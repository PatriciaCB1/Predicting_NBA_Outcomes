# %%
# !pip install statsmodels
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
import statsmodels as sm
import statsmodels.api as smi
# Out:
# Requirement already satisfied: statsmodels in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (0.12.2)
# Requirement already satisfied: numpy>=1.15 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from statsmodels) (1.19.4)
# Requirement already satisfied: scipy>=1.1 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from statsmodels) (1.6.2)
# Requirement already satisfied: patsy>=0.5 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from statsmodels) (0.5.1)
# Requirement already satisfied: pandas>=0.21 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from statsmodels) (1.2.0)
# Requirement already satisfied: pytz>=2017.3 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from pandas>=0.21->statsmodels) (2020.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from pandas>=0.21->statsmodels) (2.8.1)
# Requirement already satisfied: six in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (from patsy>=0.5->statsmodels) (1.15.0)
# WARNING: You are using pip version 21.0.1; however, version 21.1.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.7/bin/python3 -m pip install --upgrade pip' command.

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
import tensorflow as t
from sqlalchemy import create_engine

# %%
###"postgres://[postgres]:[NBATeam123$3]@[127.0.0.1]:[5432]/[my_data_class_db] 52497"

db_string = f"postgres://root:NBATeam123$@mypostgredb.ct8fvcfbdols.us-west-2.rds.amazonaws.com:5432/my_data_class_db"


###engine = create_engine('postgresql://scott:tiger@localhost/mydatabase')

##db_string = f"postgres://postgres:{db_password}@127.0.0.1:5432/movie_data"

engine = create_engine(db_string)

# %%
query_string = """SELECT RECORD_ID, 
SEASON_ID, 
HOME_TEAM_ID, 
GAME_ID, 
GAME_DATE,
HOME_PTS, 
HOME_FGM, 
HOME_FGA, 
HOME_FG_PCT, 
HOME_FG3M, 
HOME_FG3A, 
HOME_FG3_PCT, 
HOME_FTA, 
HOME_FT_PCT, 
HOME_OREB, 
HOME_DREB, 
HOME_REB, 
HOME_AST, 
HOME_STL, 
HOME_BLK, 
HOME_TOV, 
HOME_PF, 
HOME_PLUS_MINUS, 
HOME_WIN, 
AWAY_TEAM_ID, 
AWAY_PTS, 
AWAY_FGM, 
AWAY_FGA, 
AWAY_FG_PCT, 
AWAY_FG3M, 
AWAY_FG3A, 
AWAY_FG3_PCT, 
AWAY_FTA, 
AWAY_FT_PCT, 
AWAY_OREB, 
AWAY_DREB, 
AWAY_REB, 
AWAY_AST, 
AWAY_STL, 
WAY_BLK, 
AWAY_TOV, 
AWAY_PF, 
AWAY_PLUS_MINUS,
TEAM_ID,
LEAGUE_ID,
SEASON_ID, 
STANDINGSDATE,
CONFERENCE,
TEAM,
G,
W,
L,
W_PCT,
HOME_RECORD,
ROAD_RECORD,
RETURNTOPLAY,
team_type
"""
query_df = pd.read_sql(query_string, django.db.connection)
query_df.to_csv(output_file_path, encoding="utf-8", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-d21db61e9966> in <module>
#      57 team_type
#      58 """
# ---> 59 query_df = pd.read_sql(query_string, django.db.connection)
#      60 query_df.to_csv(output_file_path, encoding="utf-8", index=False)
#
# NameError: name 'django' is not defined

# %%
games_df = pd.read_sql("SELECT * from nba_data", db_string)
games_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17839 entries, 0 to 17838
# Data columns (total 55 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   SEASON_ID        17839 non-null  int64
#  1   HOME_TEAM_ID     17839 non-null  int64
#  2   GAME_ID          17839 non-null  float64
#  3   GAME_DATE        17839 non-null  object
#  4   HOME_PTS         17839 non-null  int64
#  5   HOME_FGM         17839 non-null  int64
#  6   HOME_FGA         17839 non-null  int64
#  7   HOME_FG_PCT      17839 non-null  float64
#  8   HOME_FG3M        17839 non-null  int64
#  9   HOME_FG3A        17839 non-null  int64
#  10  HOME_FG3_PCT     17839 non-null  float64
#  11  HOME_FTA         17839 non-null  int64
#  12  HOME_FT_PCT      17839 non-null  float64
#  13  HOME_OREB        17839 non-null  int64
#  14  HOME_DREB        17839 non-null  int64
#  15  HOME_REB         17839 non-null  int64
#  16  HOME_AST         17839 non-null  int64
#  17  HOME_STL         17839 non-null  int64
#  18  HOME_BLK         17839 non-null  int64
#  19  HOME_TOV         17839 non-null  int64
#  20  HOME_PF          17839 non-null  int64
#  21  HOME_PLUS_MINUS  17839 non-null  float64
#  22  HOME_WIN         17839 non-null  int64
#  23  AWAY_TEAM_ID     17839 non-null  int64
#  24  AWAY_PTS         17839 non-null  int64
#  25  AWAY_FGM         17839 non-null  int64
#  26  AWAY_FGA         17839 non-null  int64
#  27  AWAY_FG_PCT      17839 non-null  float64
#  28  AWAY_FG3M        17839 non-null  int64
#  29  AWAY_FG3A        17839 non-null  int64
#  30  AWAY_FG3_PCT     17839 non-null  float64
#  31  AWAY_FTA         17839 non-null  int64
#  32  AWAY_FT_PCT      17839 non-null  float64
#  33  AWAY_OREB        17839 non-null  int64
#  34  AWAY_DREB        17839 non-null  int64
#  35  AWAY_REB         17839 non-null  int64
#  36  AWAY_AST         17839 non-null  int64
#  37  AWAY_STL         17839 non-null  int64
#  38  WAY_BLK          17839 non-null  int64
#  39  AWAY_TOV         17839 non-null  int64
#  40  AWAY_PF          17839 non-null  int64
#  41  AWAY_PLUS_MINUS  17839 non-null  float64
#  42  TEAM_ID          17839 non-null  int64
#  43  LEAGUE_ID        17839 non-null  int64
#  44  STANDINGSDATE    17839 non-null  object
#  45  CONFERENCE       17839 non-null  object
#  46  TEAM             17839 non-null  object
#  47  G                17839 non-null  int64
#  48  W                17839 non-null  int64
#  49  L                17839 non-null  int64
#  50  W_PCT            17839 non-null  float64
#  51  HOME_RECORD      17839 non-null  object
#  52  ROAD_RECORD      17839 non-null  object
#  53  RETURNTOPLAY     371 non-null    object
#  54  team_type        17839 non-null  object
# dtypes: float64(10), int64(37), object(8)
# memory usage: 7.5+ MB

# %%
# Import our input dataset

#games_df = games_df.drop(["GAME_DATE_EST", "GAME_ID","GAME_STATUS_TEXT", "HOME_TEAM_ID", "VISITOR_TEAM_ID", "TEAM_ID_home", "TEAM_ID_away"], axis=1)

games_df = games_df.drop(["RETURNTOPLAY", "GAME_DATE", "STANDINGSDATE", "LEAGUE_ID", "HOME_RECORD", "ROAD_RECORD", "CONFERENCE", "TEAM", "team_type"], axis=1)


games_df = games_df.dropna()

#games_df = pd.get_dummies(games_df, columns = ['team_type'])

games_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17839 entries, 0 to 17838
# Data columns (total 46 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   SEASON_ID        17839 non-null  int64
#  1   HOME_TEAM_ID     17839 non-null  int64
#  2   GAME_ID          17839 non-null  float64
#  3   HOME_PTS         17839 non-null  int64
#  4   HOME_FGM         17839 non-null  int64
#  5   HOME_FGA         17839 non-null  int64
#  6   HOME_FG_PCT      17839 non-null  float64
#  7   HOME_FG3M        17839 non-null  int64
#  8   HOME_FG3A        17839 non-null  int64
#  9   HOME_FG3_PCT     17839 non-null  float64
#  10  HOME_FTA         17839 non-null  int64
#  11  HOME_FT_PCT      17839 non-null  float64
#  12  HOME_OREB        17839 non-null  int64
#  13  HOME_DREB        17839 non-null  int64
#  14  HOME_REB         17839 non-null  int64
#  15  HOME_AST         17839 non-null  int64
#  16  HOME_STL         17839 non-null  int64
#  17  HOME_BLK         17839 non-null  int64
#  18  HOME_TOV         17839 non-null  int64
#  19  HOME_PF          17839 non-null  int64
#  20  HOME_PLUS_MINUS  17839 non-null  float64
#  21  HOME_WIN         17839 non-null  int64
#  22  AWAY_TEAM_ID     17839 non-null  int64
#  23  AWAY_PTS         17839 non-null  int64
#  24  AWAY_FGM         17839 non-null  int64
#  25  AWAY_FGA         17839 non-null  int64
#  26  AWAY_FG_PCT      17839 non-null  float64
#  27  AWAY_FG3M        17839 non-null  int64
#  28  AWAY_FG3A        17839 non-null  int64
#  29  AWAY_FG3_PCT     17839 non-null  float64
#  30  AWAY_FTA         17839 non-null  int64
#  31  AWAY_FT_PCT      17839 non-null  float64
#  32  AWAY_OREB        17839 non-null  int64
#  33  AWAY_DREB        17839 non-null  int64
#  34  AWAY_REB         17839 non-null  int64
#  35  AWAY_AST         17839 non-null  int64
#  36  AWAY_STL         17839 non-null  int64
#  37  WAY_BLK          17839 non-null  int64
#  38  AWAY_TOV         17839 non-null  int64
#  39  AWAY_PF          17839 non-null  int64
#  40  AWAY_PLUS_MINUS  17839 non-null  float64
#  41  TEAM_ID          17839 non-null  int64
#  42  G                17839 non-null  int64
#  43  W                17839 non-null  int64
#  44  L                17839 non-null  int64
#  45  W_PCT            17839 non-null  float64
# dtypes: float64(10), int64(36)
# memory usage: 6.4 MB

# %%
X = games_df[['SEASON_ID', 
'HOME_TEAM_ID', 
'GAME_ID', 
'HOME_PTS', 
'HOME_FGM', 
'HOME_FGA', 
'HOME_FG_PCT', 
'HOME_FG3M', 
'HOME_FG3A', 
'HOME_FG3_PCT', 
'HOME_FTA', 
'HOME_FT_PCT', 
'HOME_OREB', 
'HOME_DREB', 
'HOME_REB', 
'HOME_AST', 
'HOME_STL', 
'HOME_BLK', 
'HOME_TOV', 
'HOME_PF', 
'HOME_PLUS_MINUS',  
'AWAY_TEAM_ID', 
'AWAY_PTS', 
'AWAY_FGM', 
'AWAY_FGA', 
'AWAY_FG_PCT', 
'AWAY_FG3M', 
'AWAY_FG3A', 
'AWAY_FG3_PCT', 
'AWAY_FTA', 
'AWAY_FT_PCT', 
'AWAY_OREB', 
'AWAY_DREB', 
'AWAY_REB', 
'AWAY_AST', 
'AWAY_STL', 
'WAY_BLK', 
'AWAY_TOV', 
'AWAY_PF', 
'AWAY_PLUS_MINUS',
'TEAM_ID',
'SEASON_ID', 
'G',
'W',
'L',
'W_PCT',
]]
y = games_df['HOME_WIN']

# %%
regr = linear_model.LinearRegression()
regr.fit(X, y)
# Out:
# LinearRegression()

# %%
print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# Intercept:
#  -478239.4829819063
# Coefficients:
#  [ 1.80865044e-07 -2.32832527e-10  1.22302316e-11  2.22067643e-02
#  -1.16400612e-02 -5.98881879e-03  1.07824867e+00 -3.85079244e-03
#  -4.74466588e-04  1.65213764e-01 -3.28834799e-03 -7.40172897e-04
#   5.66755210e-03 -1.26711287e-03  4.40043923e-03  5.66058317e-04
#  -3.16400008e-04  1.88796076e-03 -1.01685857e-02 -9.07141936e-03
#  -2.71782060e-03  6.57708483e-11 -2.75381728e-02  2.33089762e-02
#   3.80581448e-03 -9.15959401e-01  5.68348287e-03  2.20722684e-03
#  -1.48386410e-01  7.97086602e-03  8.11014915e-02 -5.46044159e-03
#   2.87029419e-03 -2.59014740e-03  1.59036499e-03 -2.64534785e-03
#  -2.30698887e-03  1.26576608e-02  7.73111105e-03 -7.62088789e-03
#   2.96930507e-04  1.80990739e-07 -2.22427574e-04 -2.77562136e-04
#   5.51345560e-05  2.02236614e-02]

# %%
# with statsmodels
X = smi.add_constant(X) # adding a constant

# %%
model = smi.OLS(y, X).fit()
predictions = model.predict(X)

# %%
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               HOME_WIN   R-squared:                       0.661
# Model:                            OLS   Adj. R-squared:                  0.661
# Method:                 Least Squares   F-statistic:                     847.8
# Date:                Tue, 11 May 2021   Prob (F-statistic):               0.00
# Time:                        20:18:18   Log-Likelihood:                -3105.0
# No. Observations:               17839   AIC:                             6294.
# Df Residuals:                   17797   BIC:                             6621.
# Df Model:                          41
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            7.078e-08    1.2e-08      5.889      0.000    4.72e-08    9.43e-08
# SEASON_ID        3.645e-08   2.29e-07      0.159      0.873   -4.12e-07    4.85e-07
# HOME_TEAM_ID    -2.333e-10   2.55e-11     -9.155      0.000   -2.83e-10   -1.83e-10
# GAME_ID          1.186e-11   8.57e-12      1.384      0.166   -4.93e-12    2.86e-11
# HOME_PTS            0.0222      0.004      6.273      0.000       0.015       0.029
# HOME_FGM           -0.0117      0.007     -1.572      0.116      -0.026       0.003
# HOME_FGA           -0.0060      0.002     -2.497      0.013      -0.011      -0.001
# HOME_FG_PCT         1.0780      0.411      2.621      0.009       0.272       1.884
# HOME_FG3M          -0.0039      0.004     -0.940      0.347      -0.012       0.004
# HOME_FG3A          -0.0005      0.001     -0.449      0.653      -0.003       0.002
# HOME_FG3_PCT        0.1659      0.080      2.071      0.038       0.009       0.323
# HOME_FTA           -0.0033      0.002     -1.477      0.140      -0.008       0.001
# HOME_FT_PCT        -0.0008      0.061     -0.013      0.990      -0.120       0.119
# HOME_OREB           0.0056      0.001      7.005      0.000       0.004       0.007
# HOME_DREB          -0.0013      0.001     -1.791      0.073      -0.003       0.000
# HOME_REB            0.0044      0.001      7.911      0.000       0.003       0.005
# HOME_AST            0.0005      0.001      0.904      0.366      -0.001       0.002
# HOME_STL           -0.0003      0.001     -0.272      0.785      -0.003       0.002
# HOME_BLK            0.0019      0.001      1.894      0.058   -6.62e-05       0.004
# HOME_TOV           -0.0102      0.001     -8.223      0.000      -0.013      -0.008
# HOME_PF            -0.0091      0.001    -10.430      0.000      -0.011      -0.007
# HOME_PLUS_MINUS    -0.0027      0.005     -0.584      0.560      -0.012       0.006
# AWAY_TEAM_ID     6.575e-11   6.32e-11      1.040      0.298   -5.82e-11     1.9e-10
# AWAY_PTS           -0.0274      0.004     -7.701      0.000      -0.034      -0.020
# AWAY_FGM            0.0232      0.007      3.152      0.002       0.009       0.038
# AWAY_FGA            0.0038      0.002      1.603      0.109      -0.001       0.008
# AWAY_FG_PCT        -0.9155      0.405     -2.258      0.024      -1.710      -0.121
# AWAY_FG3M           0.0056      0.004      1.387      0.165      -0.002       0.014
# AWAY_FG3A           0.0022      0.001      1.990      0.047    3.29e-05       0.004
# AWAY_FG3_PCT       -0.1474      0.078     -1.878      0.060      -0.301       0.006
# AWAY_FTA            0.0079      0.002      3.573      0.000       0.004       0.012
# AWAY_FT_PCT         0.0799      0.063      1.277      0.202      -0.043       0.202
# AWAY_OREB          -0.0055      0.001     -6.767      0.000      -0.007      -0.004
# AWAY_DREB           0.0029      0.001      4.153      0.000       0.002       0.004
# AWAY_REB           -0.0026      0.001     -4.606      0.000      -0.004      -0.001
# AWAY_AST            0.0016      0.001      2.596      0.009       0.000       0.003
# AWAY_STL           -0.0027      0.001     -2.308      0.021      -0.005      -0.000
# WAY_BLK            -0.0023      0.001     -2.416      0.016      -0.004      -0.000
# AWAY_TOV            0.0126      0.001     10.110      0.000       0.010       0.015
# AWAY_PF             0.0077      0.001      8.962      0.000       0.006       0.009
# AWAY_PLUS_MINUS    -0.0077      0.004     -1.797      0.072      -0.016       0.001
# TEAM_ID          3.617e-10   1.75e-10      2.063      0.039     1.8e-11    7.05e-10
# SEASON_ID        2.978e-07   2.28e-07      1.307      0.191   -1.49e-07    7.45e-07
# G                  -0.0002   5.67e-05     -3.957      0.000      -0.000      -0.000
# W                  -0.0003      0.000     -1.323      0.186      -0.001       0.000
# L                4.871e-05      0.000      0.236      0.814      -0.000       0.000
# W_PCT               0.0201      0.019      1.073      0.283      -0.017       0.057
# ==============================================================================
# Omnibus:                     1954.117   Durbin-Watson:                   0.986
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              569.911
# Skew:                           0.105   Prob(JB):                    1.76e-124
# Kurtosis:                       2.150   Cond. No.                     2.06e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.26e-12. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
from mlxtend.plotting import plot_confusion_matrix
import matplotlib.pyplot as plt
import numpy as np

binary1 = np.array([[2033, 515],
                   [662, 1250]])

fig, ax = plot_confusion_matrix(conf_mat=binary1)
plt.show()
